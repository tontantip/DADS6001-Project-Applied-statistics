# %%
##  Y maze: % correct alternations out of total number of alternations (3xTg mice)
mice_CTRL <- c(44.4, 10.0, 50.0, 0.0, 60.0, 52.9, 70.0, 50.0, 28.6, 62.5, 23.8, 42.1, 100.0, 30.0, 38.9, 30.0, 40.0, 20.0, 25.0, 46.5, 62.5, 66.7, 33.3, 47.4, 38.9, 51.2, 72.7)
mice_DEF <- c(45.5, 0.0, 57.1, 30.0, 33.3, 14.3, 27.3, 16.7, 25.0, 0.0, 66.7, 30.8, 25.0, 27.3, 28.6, 28.6, 12.5)

# %%
## Number of each data
n_CTRL <- length(mice_CTRL)
n_CTRL
n_DEF <- length(mice_DEF)
n_DEF
# Out:
# [1] 27
# [1] 17

# %%
## Mean and Standard deviation
Mean_CTRL <- mean(mice_CTRL)
Mean_CTRL
Mean_DEF <- mean(mice_DEF)
Mean_DEF
SD_CTRL <- sd(mice_CTRL)
SD_CTRL
SD_DEF <- sd(mice_DEF)
SD_DEF
# Out:
# [1] 44.34815
# [1] 27.57059
# [1] 21.08732
# [1] 17.37612

# %%
## qqplot
qqnorm(mice_CTRL)
qqline(mice_CTRL)
qqnorm(mice_DEF)
qqline(mice_DEF)
# Out:
# Plot with title “Normal Q-Q Plot”
# Plot with title “Normal Q-Q Plot”

# %%
## Normality
shapiro.test(mice_CTRL)
shapiro.test(mice_DEF)

## Homogeneity of Variances
var.test(mice_DEF, mice_CTRL, alternative = "two.sided")
# Out:
# 	Shapiro-Wilk normality test
#
# data:  mice_CTRL
# W = 0.98442, p-value = 0.9456
# 	Shapiro-Wilk normality test
#
# data:  mice_DEF
# W = 0.92912, p-value = 0.2104
# 	F test to compare two variances
#
# data:  mice_DEF and mice_CTRL
# F = 0.67899, num df = 16, denom df = 26, p-value = 0.4237
# alternative hypothesis: true ratio of variances is not equal to 1
# 95 percent confidence interval:
#  0.287746 1.767629
# sample estimates:
# ratio of variances
#          0.6789898

# %%
## Two Sample t-test
t.test(mice_DEF, mice_CTRL, alternative = "less")
# Out:
# 	Welch Two Sample t-test
#
# data:  mice_DEF and mice_CTRL
# t = -2.8676, df = 38.866, p-value = 0.003324
# alternative hypothesis: true difference in means is less than 0
# 95 percent confidence interval:
#      -Inf -6.91913
# sample estimates:
# mean of x mean of y
#  27.57059  44.34815
